# %% [markdown]
# <a href="https://colab.research.google.com/github/melikaminari/DataJournalism/blob/main/2023newsit_scraper.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time
import numpy as np
import matplotlib.pyplot as plt
import spacy

# %%
# !python -m spacy download el_core_news_sm
# Out:
# 2023-07-12 16:00:47.709746: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.6/12.6 MB 62.1 MB/s eta 0:00:00
# ...
# ✔ Download and installation successful
# You can now load the package via spacy.load('el_core_news_sm')

# %%
start_page = 1
end_page = 5
start_url = 'https://www.newsit.gr/tags/tourismos/page/'

test_url = start_url + str(start_page)

# %%
response = requests.get(test_url)
doc = BeautifulSoup(response.text, 'html.parser')

# %%
newsit_teaser_articles_list = doc.find('main', {'class': 'site-main'}).find_all('article')

# %%
newsit_teaser_articles_list[0]
# Out:
# <article class="">
# <div class="image">
# <a href="https://www.newsit.gr/topikes-eidhseis/samos-stous-pente-koryfaious-proorismous-tis-xoras-symfona-me-taksidiotiki-istoselida/3815010/" style="background-image:url('https://www.newsit.gr/wp-content/uploads/2023/06/iStock-1372179190-768x544.jpg');" title="Το νησί - έκπληξη που βρίσκεται στη «χρυσή» πεντάδα της χώρας στη φετινή σκληρή μάχη του τουρισμού"></a>
# </div>
# <div>
# <div class="entry-meta mb-05">
# <span class="posted-on">
# <time class="entry-date published" datetime="2023-07-10T09:09:03+03:00">
# <svg aria-hidden="true" height="12" role="img" version="1.1" viewbox="0 0 12 12" width="12" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <path class="st0" d="M6,0C2.7,0,0,2.7,0,6s2.7,6,6,6s6-2.7,6-6S9.3,0,6,0z M6,11C3.3,11,1,8.7,1,6S3.3,1.1,6,1.1s5,2.2,5,4.9
# 	S8.7,11,6,11z"></path>
# ...

# %%
print(newsit_teaser_articles_list[0].prettify())
# Out:
# <article class="">
#  <div class="image">
#   <a href="https://www.newsit.gr/topikes-eidhseis/samos-stous-pente-koryfaious-proorismous-tis-xoras-symfona-me-taksidiotiki-istoselida/3815010/" style="background-image:url('https://www.newsit.gr/wp-content/uploads/2023/06/iStock-1372179190-768x544.jpg');" title="Το νησί - έκπληξη που βρίσκεται στη «χρυσή» πεντάδα της χώρας στη φετινή σκληρή μάχη του τουρισμού">
#   </a>
#  </div>
#  <div>
#   <div class="entry-meta mb-05">
#    <span class="posted-on">
#     <time class="entry-date published" datetime="2023-07-10T09:09:03+03:00">
#      <svg aria-hidden="true" height="12" role="img" version="1.1" viewbox="0 0 12 12" width="12" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#       <path class="st0" d="M6,0C2.7,0,0,2.7,0,6s2.7,6,6,6s6-2.7,6-6S9.3,0,6,0z M6,11C3.3,11,1,8.7,1,6S3.3,1.1,6,1.1s5,2.2,5,4.9
# 	S8.7,11,6,11z">
#       </path>
# ...

# %%
link = newsit_teaser_articles_list[0].find('a', {'class': ''})['href']
print(link)
# Out:
# https://www.newsit.gr/topikes-eidhseis/samos-stous-pente-koryfaious-proorismous-tis-xoras-symfona-me-taksidiotiki-istoselida/3815010/

# %%
main_url = 'https://www.newsit.gr'
article_link = main_url + link
print(article_link)
# Out:
# https://www.newsit.grhttps://www.newsit.gr/topikes-eidhseis/samos-stous-pente-koryfaious-proorismous-tis-xoras-symfona-me-taksidiotiki-istoselida/3815010/

# %%
newsit_teasers_list = []

for page_num in range(start_page, end_page+1):
  page_url = start_url + str(page_num)
  response = requests.get(page_url)
  doc = BeautifulSoup(response.text, 'html.parser')

  #*** ΔΩΣΤΕ ΤΗ ΔΙΚΗ ΣΑΣ ΤΙΜΗ στo teaser_articles_list***
  newsit_teaser_articles_list = doc.find('main', {'class': 'site-main'}).find_all('article')


  for teaser in newsit_teaser_articles_list:
      story_dict = {}
      try:

        #*** ΔΩΣΤΕ ΤΗ ΔΙΚΗ ΣΑΣ ΤΙΜΗ στο link, ΜΕΤΑ το teaser
        link = teaser.find('a', {'class': ""})['href']


        if link.startswith("http"):
          story_dict['url'] = link
        else:
          story_dict['url'] = main_url + link
      except:
        story_dict['url'] = ''
        pass
      newsit_teasers_list.append(story_dict)
  time.sleep(1)

# %%
newsit_teasers_df = pd.DataFrame(newsit_teasers_list)
newsit_teasers_df
# Out:
#                                                   url
# 0   https://www.newsit.gr/topikes-eidhseis/samos-s...
# 1   https://www.newsit.gr/topikes-eidhseis/aktoplo...
# 2   https://www.newsit.gr/topikes-eidhseis/tinos-o...
# 3   https://www.newsit.gr/ellada/ayksimeni-i-touri...
# 4   https://www.newsit.gr/topikes-eidhseis/tourism...
# ..                                                ...
# 95  https://www.newsit.gr/politikh/kikilias-o-kaly...
# 96  https://www.newsit.gr/politikh/kyriakos-mitsot...
# 97  https://www.newsit.gr/politikh/vasilis-kikilia...
# 98  https://www.newsit.gr/politikh/proypologismos-...
# 99  https://www.newsit.gr/politikh/vasilis-kikilia...
#
# [100 rows x 1 columns]

# %%
newsit_teasers_df.to_csv('/content/drive/MyDrive/1o scraper.ipynb', index=False)

# %%
article_url ='https://www.newsit.gr/topikes-eidhseis/tinos-o-tourismos-kai-i-syntagi-tis-apogeiosis-to-diktyo-ton-150-xiliometron/3814588/'

# %%
response = requests.get(article_url)
doc = BeautifulSoup(response.text, 'html.parser')

# %%
article = doc.find('div', {'class': 'inside-article'})
print(article.prettify())
# Out:
# <div class="inside-article">
#  <header class="entry-header">
#   <div class="entry-meta">
#    <span class="posted-on">
#     <time class="entry-date published" datetime="2023-07-09T13:20:41+03:00" itemprop="datePublished">
#      <svg aria-hidden="true" height="12" role="img" version="1.1" viewbox="0 0 12 12" width="12" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#       <path class="st0" d="M6,0C2.7,0,0,2.7,0,6s2.7,6,6,6s6-2.7,6-6S9.3,0,6,0z M6,11C3.3,11,1,8.7,1,6S3.3,1.1,6,1.1s5,2.2,5,4.9
# 	S8.7,11,6,11z">
#       </path>
#       <path class="st0" d="M6.6,6V2.7c0-0.3-0.3-0.4-0.5-0.4H5.9c-0.3,0-0.5,0.3-0.5,0.4v3.6c0,0.2,0,0.5,0.3,0.5l1.8,1.4
# 	c0.1,0.1,0.1,0.1,0.3,0.1s0.3,0,0.3-0.1l0,0V7.8c0.1-0.2,0.1-0.5-0.1-0.6L6.6,6z">
#       </path>
#      </svg>
#      13:20 09/07/2023
#     </time>
#    </span>
#   </div>
#   <h1 class="entry-title" itemprop="headline">
#    Τήνος: Ο τουρισμός και η συνταγή της απογείωσης – Το δίκτυο των 150 χιλιομέτρων
# ...

# %%
section = doc.find('div', {'class': 'grid-container grid-parent'}).text
section
# Out:
# '\nNewsIT Τοπικα Νεα Αυτο ειναι το νησι των Κυκλαδων με την ξεχωριστη «συνταγη» για την απογειωση του τουρισμου\n'

# %%
title = article.find('h1').text
title
# Out:
# 'Τήνος: Ο τουρισμός και η συνταγή της απογείωσης – Το δίκτυο των 150 χιλιομέτρων'

# %%
date = article.find('time')['datetime']
date
# Out:
# '2023-07-09T13:20:41+03:00'

# %%
paragraphs = article.find_all('p')
paragraphs
# Out:
# [<p>Η <a href="https://www.newsit.gr/tags/tinos/" rel="noopener" target="_blank">Τήνος</a> δίνει τη δική της μάχη και ο <a href="https://www.newsit.gr/tags/tourismos/" rel="noopener" target="_blank">τουρισμός</a> πηγαίνει για την ώρα περίφημα. Στο νησί των Κυκλάδων κάνουν σχέδια για να επιμηκύνουν την τουριστική περίοδο…</p>,
#  <p>Στην καθιέρωση της Τήνου, ως έναν τουριστικό προορισμό που θα αποτελεί βασικό σταθμό για τους λάτρεις των εναλλακτικών μορφών τουρισμού στοχεύει η δημοτική αρχή του νησιού αναδεικνύοντας μεταξύ άλλων τις πεζοπορικές διαδρομές του. Μέσα από ένα πεζοπορικό δίκτυο που ξεπερνά τα 150 χιλιόμετρα, ο επισκέπτης θα ανακαλύψει ένα αυθεντικό και συνάμα ανεξερεύνητο νησί των Κυκλάδων, που είναι φιλόξενο και εντυπωσιακό σε όλες τις εποχές του χρόνου. </p>,
#  <p class="advert-badge align-center"></p>,
# ...

# %%
p_texts_list = []
paragraphs = article.find_all('p')
for p in paragraphs:
  p_texts_list.append(p.text)
full_text = ' '.join(p_texts_list)
full_text = "".join(full_text.splitlines())
full_text
# Out:
# 'Η Τήνος δίνει τη δική της μάχη και ο τουρισμός πηγαίνει για την ώρα περίφημα. Στο νησί των Κυκλάδων κάνουν σχέδια για να επιμηκύνουν την τουριστική περίοδο… Στην καθιέρωση της Τήνου, ως έναν τουριστικό προορισμό που θα αποτελεί βασικό σταθμό για τους λάτρεις των εναλλακτικών μορφών τουρισμού στοχεύει η δημοτική αρχή του νησιού αναδεικνύοντας μεταξύ άλλων τις πεζοπορικές διαδρομές του. Μέσα από ένα πεζοπορικό δίκτυο που ξεπερνά τα 150 χιλιόμετρα, ο επισκέπτης θα ανακαλύψει ένα αυθεντικό και συνάμα ανεξερεύνητο νησί των Κυκλάδων, που είναι φιλόξενο και εντυπωσιακό σε όλες τις εποχές του χρόνου.   Με ομπρέλα την επικοινωνιακή πλατφόρμα, “ΜονοπαΤήνος” \xa0που υλοποίησε ο δήμος, όλος ο πολιτιστικός πλούτος του νησιού ξετυλίγεται στα σηματοδοτημένα μονοπάτια του νησιού. «Η Τήνος μπορεί να πρωταγωνιστήσει στον περιπατητικό τουρισμού και να ελκύσει επισκέπτες από όλο τον κόσμο. Κάτι που φυσικά και τώρα γίνεται», όπως εξηγεί στο ΑΠΕ-ΜΠΕ ο Μάνθος Πρελορέντζο / διοργανωτής Tinos Outdoor Activi
# ...

# %%
newsit_teasers_df = pd.read_csv('/content/drive/MyDrive/1o scraper.ipynb')
newsit_teasers_df.head()
# Out:
#                                                  url
# 0  https://www.newsit.gr/topikes-eidhseis/samos-s...
# 1  https://www.newsit.gr/topikes-eidhseis/aktoplo...
# 2  https://www.newsit.gr/topikes-eidhseis/tinos-o...
# 3  https://www.newsit.gr/ellada/ayksimeni-i-touri...
# 4  https://www.newsit.gr/topikes-eidhseis/tourism...

# %%
full_articles_list = []

for article_url in newsit_teasers_df['url']:
  response = requests.get(article_url)
  doc = BeautifulSoup(response.text, 'html.parser')

  #*** ΔΩΣΤΕ ΤΗ ΔΙΚΗ ΣΑΣ ΤΙΜΗ στo article που βρήκατε παραπάνω***
  article = doc.find('div', {'class': 'inside-article'})

  full_article_dict = {}

  # website
  full_article_dict['site'] = "https://www.newsit.gr/"

  # url
  full_article_dict['url'] = article_url

  #section
  try:
    section = doc.find('div', {'class': 'grid-container grid-parent'}).text
    full_article_dict['section'] = section
  except:
    full_article_dict['section'] = ''
    pass

  #title
  try:
    title = title = article.find('h1').text
    full_article_dict['title'] = title
  except:
    full_article_dict['title'] = ''
    pass

  # date
  try:
    date = article.find('time')['datetime']
    full_article_dict['date'] = date
  except:
    full_article_dict['date'] = ''
    pass

  # author
  try:
    author = article.find('div', {'class', "article__author"}).span.text
    full_article_dict['author'] = author
  except:
    full_article_dict['author'] = ''
    pass

  # full_text
  try:
    p_texts_list = []
    paragraphs = article.find_all('p')
    for p in paragraphs:
      p_texts_list.append(p.text)
    full_text = ' '.join(p_texts_list)
    full_text = "".join(full_text.splitlines())
    full_article_dict['full_text'] = full_text
  except:
    full_article_dict['full_text'] = ''
    pass

  full_articles_list.append(full_article_dict)
  time.sleep(1)

# %%
newsit_full_articles_df.dropna(inplace=True)

# %%
newsit_full_articles_df.drop_duplicates(inplace=True)

# %%
newsit_full_articles_df = pd.DataFrame(full_articles_list)
newsit_full_articles_df
# Out:
#                       site                                                url  \
# 0   https://www.newsit.gr/  https://www.newsit.gr/topikes-eidhseis/samos-s...
# 1   https://www.newsit.gr/  https://www.newsit.gr/topikes-eidhseis/aktoplo...
# 2   https://www.newsit.gr/  https://www.newsit.gr/topikes-eidhseis/tinos-o...
# 3   https://www.newsit.gr/  https://www.newsit.gr/ellada/ayksimeni-i-touri...
# 4   https://www.newsit.gr/  https://www.newsit.gr/topikes-eidhseis/tourism...
# ..                     ...                                                ...
# 95  https://www.newsit.gr/  https://www.newsit.gr/politikh/kikilias-o-kaly...
# 96  https://www.newsit.gr/  https://www.newsit.gr/politikh/kyriakos-mitsot...
# 97  https://www.newsit.gr/  https://www.newsit.gr/politikh/vasilis-kikilia...
# 98  https://www.newsit.gr/  https://www.newsit.gr/politikh/proypologismos-...
# 99  https://www.newsit.gr/  https://www.newsit.gr/politikh/vasilis-kikilia...
#
# ...

# %%
newsit_full_articles_df.to_csv('/content/drive/MyDrive/1o scraper.ipynb.csv', index=False)

# %%
newsit_full_articles_df['datetime'] = pd.to_datetime(newsit_full_articles_df['date'], format='%Y-%m-%d %H:%M')
newsit_full_articles_df.head()
# Out:
#                      site                                                url  \
# 0  https://www.newsit.gr/  https://www.newsit.gr/topikes-eidhseis/samos-s...
# 1  https://www.newsit.gr/  https://www.newsit.gr/topikes-eidhseis/aktoplo...
# 2  https://www.newsit.gr/  https://www.newsit.gr/topikes-eidhseis/tinos-o...
# 3  https://www.newsit.gr/  https://www.newsit.gr/ellada/ayksimeni-i-touri...
# 4  https://www.newsit.gr/  https://www.newsit.gr/topikes-eidhseis/tourism...
#
#                                              section  \
# 0  \nNewsIT Τοπικα Νεα Το νησι - εκπληξη που βρισ...
# 1  \nNewsIT Τοπικα Νεα Αυξησεις «φωτια» στα ακτοπ...
# 2  \nNewsIT Τοπικα Νεα Αυτο ειναι το νησι των Κυκ...
# 3  \nNewsIT Ελλαδα Αυξημενη η τουριστικη κινηση σ...
# 4  \nNewsIT Τοπικα Νεα Δειτε τα ελληνικα νησια πο...
#
#                                                title  \
# 0  Σάμος: Στους πέντε κορυφαίους προορισμούς της ...
# 1  Ακτοπλοϊκά εισιτήρια: Οι αυξήσεις και τα νησιά...
# ...
